# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\soura\\Desktop'

# %%
os.chdir('C:/Users/soura/Desktop')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mydata=pd.read_csv('windstorm_one.csv')

# %%
mydata
# Out:
#          yr  mo  dy      time  stf  mag  inj    len  minutes  fc
# 0      1950   1   3  11:00:00   29    3    3   9.50      660   0
# 1      1950   1   3  11:55:00   17    3    3   3.60      715   0
# 2      1950   1   3  16:00:00   39    1    1   0.10      960   0
# 3      1950   1  13  05:25:00    5    3    1   0.60      325   0
# 4      1950   1  25  19:30:00   29    2    5   2.30     1170   0
# 5      1950   1  25  21:00:00   17    2    0   0.10     1260   0
# 6      1950   1  26  18:00:00   48    2    2   4.70     1080   0
# 7      1950   2  11  13:10:00   48    2    0   9.90      790   0
# 8      1950   2  11  13:50:00   48    3   12  12.00      830   0
# 9      1950   2  11  21:00:00   48    2    5   4.60     1260   0
# 10     1950   2  11  23:55:00   48    2    6   4.50     1435   0
# 11     1950   2  12  00:30:00   48    2    8   8.00       30   0
# 12     1950   2  12  01:15:00   48    1    0   2.30       75   0
# ...

# %%
mydata['fc']=mydata['mag']*mydata['stf']

# %%
mydata
# Out:
#          yr  mo  dy      time  stf  mag  inj    len  minutes   fc
# 0      1950   1   3  11:00:00   29    3    3   9.50      660   87
# 1      1950   1   3  11:55:00   17    3    3   3.60      715   51
# 2      1950   1   3  16:00:00   39    1    1   0.10      960   39
# 3      1950   1  13  05:25:00    5    3    1   0.60      325   15
# 4      1950   1  25  19:30:00   29    2    5   2.30     1170   58
# 5      1950   1  25  21:00:00   17    2    0   0.10     1260   34
# 6      1950   1  26  18:00:00   48    2    2   4.70     1080   96
# 7      1950   2  11  13:10:00   48    2    0   9.90      790   96
# 8      1950   2  11  13:50:00   48    3   12  12.00      830  144
# 9      1950   2  11  21:00:00   48    2    5   4.60     1260   96
# 10     1950   2  11  23:55:00   48    2    6   4.50     1435   96
# 11     1950   2  12  00:30:00   48    2    8   8.00       30   96
# 12     1950   2  12  01:15:00   48    1    0   2.30       75   48
# ...

# %%
mydata.corr()
# Out:
#                yr        mo        dy       stf       mag       inj       len  \
# yr       1.000000  0.011969  0.025657 -0.052393 -0.309027 -0.037734 -0.075686
# mo       0.011969  1.000000 -0.042629  0.000992 -0.050574 -0.025623 -0.056400
# dy       0.025657 -0.042629  1.000000  0.002549 -0.010877 -0.009754 -0.006369
# stf     -0.052393  0.000992  0.002549  1.000000 -0.022188 -0.015333 -0.039258
# mag     -0.309027 -0.050574 -0.010877 -0.022188  1.000000  0.223765  0.437395
# inj     -0.037734 -0.025623 -0.009754 -0.015333  0.223765  1.000000  0.252200
# len     -0.075686 -0.056400 -0.006369 -0.039258  0.437395  0.252200  1.000000
# minutes  0.027945 -0.028875  0.002572  0.064065 -0.038904  0.000458 -0.008962
# fc      -0.275788 -0.034174 -0.010913  0.354691  0.823647  0.163867  0.329252
#
#           minutes        fc
# yr       0.027945 -0.275788
# mo      -0.028875 -0.034174
# dy       0.002572 -0.010913
# stf      0.064065  0.354691
# mag     -0.038904  0.823647
# ...

# %%
mydata.apply(lambda x:sum(x.isnull()),axis=0)
# Out:
# yr         0
# mo         0
# dy         0
# time       0
# stf        0
# mag        0
# inj        0
# len        0
# minutes    0
# fc         0
# dtype: int64

# %%
time=mydata['time']
stf=mydata['stf']
magnitude=mydata['mag']
injury=mydata['inj']
length=mydata['len']
windspeed=mydata['fc']

# %%
ax=plt.plot(time,windspeed,'o')
plt.ylabel("fc")
plt.xlabel("time")
# Out:
# Text(0.5, 0, 'time')

# %%
mean_speed=windspeed.mean()

# %%
ax=plt.plot(time,windspeed,'o')
plt.ylabel("fc")
plt.xlabel("time")
plt.axhline(mean_speed,color='r',linestyle='-')
plt.show()

# %%
import seaborn as sns

# %%
corr=mydata.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
minute=mydata['minutes']
import statsmodels.api as sm
model=sm.OLS(windspeed,minute).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     fc   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                 2.689e+04
# Date:                Sun, 16 Jun 2019   Prob (F-statistic):               0.00
# Time:                        15:49:03   Log-Likelihood:            -2.9520e+05
# No. Observations:               60114   AIC:                         5.904e+05
# Df Residuals:                   60113   BIC:                         5.904e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# minutes        0.0224      0.000    163.979      0.000       0.022       0.023
# ...

# %%
mydata['inj']=mydata['minutes']/60

# %%
X=mydata.loc[:,['dy','mo','inj']]
y=mydata['fc']
model=sm.OLS(windspeed,X).fit()
predictions=model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     fc   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     9451.
# Date:                Sun, 16 Jun 2019   Prob (F-statistic):               0.00
# Time:                        16:17:54   Log-Likelihood:            -2.9470e+05
# No. Observations:               60114   AIC:                         5.894e+05
# Df Residuals:                   60111   BIC:                         5.894e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# dy             0.2375      0.014     17.148      0.000       0.210       0.265
# ...

# %%
#splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=2)

# %%
#instantiating multiple linear regression
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions=model.predict(X)

# %%
accuracy=model.score(X,y) #checking accuracy
print('Accuracy of the model:',accuracy)
# Out:
# Accuracy of the model: 0.0012146470327345504

# %%
plt.scatter(y,predictions)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print('slope',model.coef_)
print('intercept',model.intercept_)
# Out:
# slope [-0.04371782 -0.43048255 -0.06318947]
# intercept 27.32461563929876

# %%
import numpy as np
rmse=(np.sqrt(mean_squared_error(y,predictions)))
r2=r2_score(y,predictions)

# %%
print("the model performance with 70% confidance level ")
print("------------------------------------------")
print('RMSE is{}',format(rmse))
print('R2_score is{}',format(r2))
# Out:
# the model performance with 70% confidance level
# ------------------------------------------
# RMSE is{} 32.03345035845161
# R2_score is{} 0.0012146470327345504
